# %%
import autogen
from autogen import ConversableAgent

# %%
from utils import get_openai_api_key
OPENAI_API_KEY = get_openai_api_key()
llm_config = {"model": "gpt-5-mini","api_key":OPENAI_API_KEY}

# %%
from autogen import UserProxyAgent

# %%
import pprint

# %%
key_clause_extractor = ConversableAgent( name = "key_clause_extractor_Agent",
                                         system_message=""" You are an key clause extractor agent, your role is to review the legal content submitted and 
                                         extract the key clauses from the content""",
                                         llm_config=llm_config,
                                         human_input_mode="NEVER")

Risk_Flagger= ConversableAgent( name= "Risk_flagger_Agent",
                                system_message=""" You are an Risk Flagger Agent, your role is to flag any risk or harmful contents from the legal
                                contents""",
                                llm_config=llm_config,
                                human_input_mode="NEVER")

Final_reviewer= ConversableAgent( name= "Final_reviewer_Agent",
                                system_message=""" Final_reviewer_Agent, your role is to verify the entire legal content, and suggest any improvements if required 
                                and highlight any risky contents""",
                                llm_config=llm_config,
                                human_input_mode="NEVER")

# %%
User_proxy= UserProxyAgent( name ="UserProxyAgent",
                            human_input_mode="ALWAYS",
                            code_execution_config=False)

# %%
cordinator= ConversableAgent( name = "cordinator_Agent",
                                 system_message="""Your role is like a mediator who gets the legal content from user proxy and pass it on to individual agents
                                 which will process the content further""",
                                 llm_config=llm_config,
                                 human_input_mode="NEVER")

# %%
human_counsel = UserProxyAgent(
    name="Human_Legal_Counsel",
    human_input_mode="ALWAYS",
    code_execution_config=False,
    description="Senior Counsel who intervenes only when AI fails."
)

# %% [markdown]
# message = """The Receiving Party agrees to treat all non-public information received
#     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.
#     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.
#     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.
#     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials."""

# %%
# the messages argument in message function holds the conversation summary between the cordinator an user proxy 
# and it does not append the next conversations automatically unless its done manually
# conversation thread between each agent is seperate

# %% [raw]
# def message(recipient,messages,sender,config):
#     message= sender.chat_messages_for_summary(recipient)[-1]['content']
#     return message
#
# chat_flow= [
#              { "sender" : cordinator,
#                "recipient" : key_clause_extractor,
#                "max_turns": 1,
#                "message" : message,
#                "summary_method": "reflection_with_llm",
#              },
#              { "sender" : cordinator,
#                "recipient" : Risk_Flagger,
#                "message" : message,
#                "max_turns": 1,
#                "summary_method": "reflection_with_llm",
#              },
#              { "sender" : cordinator,
#                "recipient" : Final_reviewer,
#                "message" : message,
#                "carryover": [0,1],
#                "max_turns": 1,
#                "summary_method": "reflection_with_llm",
#              },
#
#            ]

# %%
def message(recipient, messages, sender, config):
    """
    Robustly retrieves the input document from the current chat history.
    Takes 4 arguments as required by AutoGen's internal caller.
    """
    if not messages:
        return "No input provided. Please provide the document to review."
    
    # We take the last message from the coordinator's history with the user
    # to ensure the sub-agents are working on the most recent input.
    last_msg = messages[-1].get("content", "")
    return last_msg

# %% [raw]
# Incoming message
#         ↓
# Check registered reply functions
#         ↓
# Does sender match [autogen.Agent, None]? # if you specific agent name it will apply the filter only to messages received from that agent
#         ↓
# Yes → Call trigger_human_intervention()
#         ↓
# If function returns:
#     - A string → That becomes reply
#     - None → Continue normal reply flow

# %%
def check_and_transfer(recipient, messages, sender, config):
    """
    Failure detection sensor. 
    If the last specialist failed, it sends a signal to trigger the human.
    """
    if not messages:
        return "FAILURE_SIGNAL: No messages received."
    
    last_reply = messages[-1].get("content", "")
    
    # Logic: detect if output is too short or contains error keywords
    if len(last_reply) < 20 or "error" in last_reply.lower() or "not found" in last_reply.lower():
        return f"FAILURE_SIGNAL: {sender.name} encountered an issue."
    
    return last_reply

def trigger_human_intervention(recipient, messages, sender, config):
    """
    The Escalation Brain.
    Listens to the Coordinator and interrupts if it sees 'FAILURE_SIGNAL'.
    """
    last_message = messages[-1].get("content", "")
    
    if "FAILURE_SIGNAL" in last_message:
        print(f"\n--- [SYSTEM ALERT: ESCALATING TO HUMAN DUE TO: {last_message}] ---\n")
        
        # Coordinator initiates an emergency chat with the Human
        recipient.initiate_chat(
            human_counsel,
            message=f"The automated workflow failed: {last_message}. Please provide the analysis manually to continue."
        )
        
        # Retrieve the human's input to override the failure
        human_input = recipient.last_message(human_counsel)["content"]
        return True, human_input # Returns (True, content) to override the AI reply
    
    return False, None

# 4. Registration

# Register the escalation logic to the Coordinator
cordinator.register_reply(
    [autogen.Agent, None],
    reply_func=trigger_human_intervention,
    position=0
)

# The Chain
chat_queue = [
    {
        "sender": cordinator,
        "recipient": key_clause_extractor,
        "message": message, # Uses the document loader function from previous step
        "summary_method": "last_msg",
        "max_turns": 1,
    },
    {
        "sender": cordinator,
        "recipient": Risk_Flagger,
        "message": check_and_transfer, # Inspects Extractor output
        "summary_method": "last_msg",
        "max_turns": 1,
    },
    {
        "sender": cordinator,
        "recipient": Final_reviewer,
        "message": check_and_transfer, # Inspects Risk output
        "carryover": [0, 1], # Feeds summaries to the human-like final review
        "max_turns": 1,
    }
]

# %%
cordinator.register_nested_chats(chat_queue, trigger= User_proxy)

# %%
#from autogen import initiate_chat

chats= cordinator.initiate_chat(User_proxy, message=" Please provide the legal content", max_turns=2)
# Out:
# cordinator_Agent (to UserProxyAgent):
#
#  Please provide the legal content
#
# --------------------------------------------------------------------------------
# Replying as UserProxyAgent. Provide feedback to cordinator_Agent. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.
# UserProxyAgent (to cordinator_Agent):
#
# The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.
#
# --------------------------------------------------------------------------------
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# cordinator_Agent (to key_clause_extractor_Agent):
#
# The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.
#
# --------------------------------------------------------------------------------
# key_clause_extractor_Agent (to cordinator_Agent):
#
# - Definition of Confidential Information
#   - All non-public information received from the Disclosing Party; explicitly includes “technical data, business plans, and client lists.”
#
# - Confidentiality obligation (non-disclosure/non-publication)
#   - The Receiving Party “agrees to treat all non-public information … as strictly confidential” and “shall not disclose [or] publish” the information.
#
# - Non-use / purpose limitation
#   - The Receiving Party shall not “use this information for any purpose other than evaluating the proposed business relationship.”
#
# - Prior written consent for other uses/disclosures
#   - Any use or disclosure outside the permitted purpose requires “prior written consent.”
#
# - Exclusion / carve-out for public information
#   - The obligation does not apply to information “that is publicly known through no fault of the Receiving Party.”
#
# - Return or destruction on termination
#   - “Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.”
#
# - Parties referenced
#   - Terms apply between the “Receiving Party” and the “Disclosing Party.”
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (face1ca9-c508-4143-9ab8-1c8e3412691f): Maximum turns (1) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# cordinator_Agent (to Risk_flagger_Agent):
#
# The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.
# Context:
# - Definition of Confidential Information
#   - All non-public information received from the Disclosing Party; explicitly includes “technical data, business plans, and client lists.”
#
# - Confidentiality obligation (non-disclosure/non-publication)
#   - The Receiving Party “agrees to treat all non-public information … as strictly confidential” and “shall not disclose [or] publish” the information.
#
# - Non-use / purpose limitation
#   - The Receiving Party shall not “use this information for any purpose other than evaluating the proposed business relationship.”
#
# - Prior written consent for other uses/disclosures
#   - Any use or disclosure outside the permitted purpose requires “prior written consent.”
#
# - Exclusion / carve-out for public information
#   - The obligation does not apply to information “that is publicly known through no fault of the Receiving Party.”
#
# - Return or destruction on termination
#   - “Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.”
#
# - Parties referenced
#   - Terms apply between the “Receiving Party” and the “Disclosing Party.”
#
# --------------------------------------------------------------------------------
# Risk_flagger_Agent (to cordinator_Agent):
#
# I reviewed the provided confidentiality clause. Below are the risks, why they matter, and recommended fixes (grouped by priority).
#
# High priority (practical/legal exposure)
# - No confidentiality duration or survival clause
#   - Risk: Unknown how long obligation lasts (exposure both ways). Courts often expect a finite term unless trade-secret protection intended.
#   - Fix: Add a fixed term (e.g., "for a period of X years from the date of disclosure") and a separate survival statement for trade secrets (e.g., "trade secrets remain protected for as long as they qualify as trade secrets").
#
# - No definition/standard for “non-public” or “strictly confidential”
#   - Risk: Ambiguity invites disputes about what counts as confidential; “strictly confidential” is subjective.
#   - Fix: Define “Confidential Information” precisely (include examples) and specify standard of care (e.g., “Receiving Party will protect Confidential Information with at least the same degree of care it uses for its own confidential information, but no less than reasonable care”).
#
# - No exceptions beyond “publicly known through no fault”
#   - Risk: Missing customary carve-outs (information already known to Receiving Party, independently developed, disclosed by third party without restriction, or required disclosure by law).
#   - Fix: Add standard exclusions: (a) publicly available through no breach; (b) already in Receiving Party’s possession before disclosure (with proof); (c) independently developed by Receiving Party without use of Confidential Information; (d) rightfully received from third party without restriction. Add compelled-disclosure procedure (notice to Disclosing Party, cooperation, seek protective order).
#
# - No permitted recipients or treatment of employees/affiliates/advisors
#   - Risk: Overly strict “no disclosure” may prevent reasonable internal sharing for evaluation or sharing with advisors (legal/accounting), which is impractical.
#   - Fix: Allow disclosures to Receiving Party’s employees, consultants, advisors and affiliates who have a need-to-know and are bound by confidentiality obligations at least as protective as this agreement. Require Recipient to remain liable for their breaches.
#
# Medium priority (operational/compliance risks)
# - No requirement for data security measures or breach notification
#   - Risk: Particularly where Confidential Information includes personal data or sensitive technical info, lack of security specs raises compliance and reputational risk.
#   - Fix: Specify minimum security measures (e.g., industry-standard technical and organizational measures) and a timely breach-notification obligation.
#
# - No return/destruction timing or certification
#   - Risk: “Return or destroy” without timeframe or certification leaves uncertainty and enforcement problems (esp. backups).
#   - Fix: Require return or certified destruction within a set period (e.g., 30 days) after termination/expiration, and permit Recipient to retain one archival copy for legal/ compliance recordkeeping if required (with continued confidentiality).
#
# - No “no license” / IP ownership clause
#   - Risk: Ambiguity may suggest transfer of rights or implied license to use IP.
#   - Fix: Add explicit statement that disclosure does not grant any license or transfer of intellectual property; ownership remains with Disclosing Party.
#
# - Narrow permitted purpose / prior written consent burden
#   - Risk: Restricting use strictly to “evaluating the proposed business relationship” may be impractical for follow-up integration work or limited permitted uses; always requiring prior written consent can cause delays.
#   - Fix: Clarify permitted use (e.g., evaluation and bona fide internal business purposes related to the proposed relationship) and permit disclosures to permitted recipients without separate approvals, while requiring prior written consent only for other uses.
#
# Low–medium priority (enforceability/clarity)
# - No remedies or injunctive relief language
#   - Risk: If violated, Disclosing Party may want injunctive relief; silence may hamper enforcement.
#   - Fix: Include a clause that remedies at law may be inadequate and Disclosing Party is entitled to injunctive relief and other equitable remedies in addition to monetary damages.
#
# - No limitation of liability or indemnity provisions
#   - Risk: One-sided exposure if parties expected to cap damages or allocate indemnities.
#   - Fix: If desired, include negotiated caps/exclusions or indemnity wording. If none, note parties remain subject to general law.
#
# - No governing law, jurisdiction, or dispute resolution clause
#   - Risk: Cross-border deals may trigger jurisdictional uncertainty.
#   - Fix: Add governing law and dispute-resolution forum or arbitration clause.
#
# - No treatment of personal data / regulatory compliance
#   - Risk: “Client lists” or contact info may be personal data (GDPR, CCPA, etc.). No compliance obligations or cross-border transfer safeguards.
#   - Fix: Add language requiring compliance with applicable privacy laws, and specify permitted transfers, data processing roles, and responsibilities (or a separate DPA).
#
# - No residuals/inevitable disclosure protection or carve-out
#   - Risk: Plain “no-use” may conflict with employment mobility / residual knowledge rules; also, extreme restrictions could be unenforceable.
#   - Fix: Consider a residuals clause (e.g., non-attribution of general knowledge retained in unaided memory) or specific protection for trade-secret claims and injunctive relief for inevitable disclosure.
#
# Other practical suggestions
# - Add definitions for “Disclosing Party” and “Receiving Party” and the effective date.
# - Clarify when “termination of discussions” occurs (mutual written notice, after X days of inactivity, or execution/termination of a definitive agreement).
# - Consider including a severability clause and assignment restrictions.
# - If sensitive technical data subject to export controls, add export-control compliance obligations.
#
# If you want, I can:
# - Draft a revised NDA confidentiality clause that incorporates these fixes, or
# - Produce short model language snippets for any of the specific fixes above (e.g., compelled disclosure, return/destruction certification, permitted recipients).
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (a5dc711f-af82-484c-856a-1b66e4c6a53c): Maximum turns (1) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# cordinator_Agent (to Final_reviewer_Agent):
#
# The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.
# Context:
# 0
# 1
# - Definition of Confidential Information
#   - All non-public information received from the Disclosing Party; explicitly includes “technical data, business plans, and client lists.”
#
# - Confidentiality obligation (non-disclosure/non-publication)
#   - The Receiving Party “agrees to treat all non-public information … as strictly confidential” and “shall not disclose [or] publish” the information.
#
# - Non-use / purpose limitation
#   - The Receiving Party shall not “use this information for any purpose other than evaluating the proposed business relationship.”
#
# - Prior written consent for other uses/disclosures
#   - Any use or disclosure outside the permitted purpose requires “prior written consent.”
#
# - Exclusion / carve-out for public information
#   - The obligation does not apply to information “that is publicly known through no fault of the Receiving Party.”
#
# - Return or destruction on termination
#   - “Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.”
#
# - Parties referenced
#   - Terms apply between the “Receiving Party” and the “Disclosing Party.”
# I reviewed the provided confidentiality clause. Below are the risks, why they matter, and recommended fixes (grouped by priority).
#
# High priority (practical/legal exposure)
# - No confidentiality duration or survival clause
#   - Risk: Unknown how long obligation lasts (exposure both ways). Courts often expect a finite term unless trade-secret protection intended.
#   - Fix: Add a fixed term (e.g., "for a period of X years from the date of disclosure") and a separate survival statement for trade secrets (e.g., "trade secrets remain protected for as long as they qualify as trade secrets").
#
# - No definition/standard for “non-public” or “strictly confidential”
#   - Risk: Ambiguity invites disputes about what counts as confidential; “strictly confidential” is subjective.
#   - Fix: Define “Confidential Information” precisely (include examples) and specify standard of care (e.g., “Receiving Party will protect Confidential Information with at least the same degree of care it uses for its own confidential information, but no less than reasonable care”).
#
# - No exceptions beyond “publicly known through no fault”
#   - Risk: Missing customary carve-outs (information already known to Receiving Party, independently developed, disclosed by third party without restriction, or required disclosure by law).
#   - Fix: Add standard exclusions: (a) publicly available through no breach; (b) already in Receiving Party’s possession before disclosure (with proof); (c) independently developed by Receiving Party without use of Confidential Information; (d) rightfully received from third party without restriction. Add compelled-disclosure procedure (notice to Disclosing Party, cooperation, seek protective order).
#
# - No permitted recipients or treatment of employees/affiliates/advisors
#   - Risk: Overly strict “no disclosure” may prevent reasonable internal sharing for evaluation or sharing with advisors (legal/accounting), which is impractical.
#   - Fix: Allow disclosures to Receiving Party’s employees, consultants, advisors and affiliates who have a need-to-know and are bound by confidentiality obligations at least as protective as this agreement. Require Recipient to remain liable for their breaches.
#
# Medium priority (operational/compliance risks)
# - No requirement for data security measures or breach notification
#   - Risk: Particularly where Confidential Information includes personal data or sensitive technical info, lack of security specs raises compliance and reputational risk.
#   - Fix: Specify minimum security measures (e.g., industry-standard technical and organizational measures) and a timely breach-notification obligation.
#
# - No return/destruction timing or certification
#   - Risk: “Return or destroy” without timeframe or certification leaves uncertainty and enforcement problems (esp. backups).
#   - Fix: Require return or certified destruction within a set period (e.g., 30 days) after termination/expiration, and permit Recipient to retain one archival copy for legal/ compliance recordkeeping if required (with continued confidentiality).
#
# - No “no license” / IP ownership clause
#   - Risk: Ambiguity may suggest transfer of rights or implied license to use IP.
#   - Fix: Add explicit statement that disclosure does not grant any license or transfer of intellectual property; ownership remains with Disclosing Party.
#
# - Narrow permitted purpose / prior written consent burden
#   - Risk: Restricting use strictly to “evaluating the proposed business relationship” may be impractical for follow-up integration work or limited permitted uses; always requiring prior written consent can cause delays.
#   - Fix: Clarify permitted use (e.g., evaluation and bona fide internal business purposes related to the proposed relationship) and permit disclosures to permitted recipients without separate approvals, while requiring prior written consent only for other uses.
#
# Low–medium priority (enforceability/clarity)
# - No remedies or injunctive relief language
#   - Risk: If violated, Disclosing Party may want injunctive relief; silence may hamper enforcement.
#   - Fix: Include a clause that remedies at law may be inadequate and Disclosing Party is entitled to injunctive relief and other equitable remedies in addition to monetary damages.
#
# - No limitation of liability or indemnity provisions
#   - Risk: One-sided exposure if parties expected to cap damages or allocate indemnities.
#   - Fix: If desired, include negotiated caps/exclusions or indemnity wording. If none, note parties remain subject to general law.
#
# - No governing law, jurisdiction, or dispute resolution clause
#   - Risk: Cross-border deals may trigger jurisdictional uncertainty.
#   - Fix: Add governing law and dispute-resolution forum or arbitration clause.
#
# - No treatment of personal data / regulatory compliance
#   - Risk: “Client lists” or contact info may be personal data (GDPR, CCPA, etc.). No compliance obligations or cross-border transfer safeguards.
#   - Fix: Add language requiring compliance with applicable privacy laws, and specify permitted transfers, data processing roles, and responsibilities (or a separate DPA).
#
# - No residuals/inevitable disclosure protection or carve-out
#   - Risk: Plain “no-use” may conflict with employment mobility / residual knowledge rules; also, extreme restrictions could be unenforceable.
#   - Fix: Consider a residuals clause (e.g., non-attribution of general knowledge retained in unaided memory) or specific protection for trade-secret claims and injunctive relief for inevitable disclosure.
#
# Other practical suggestions
# - Add definitions for “Disclosing Party” and “Receiving Party” and the effective date.
# - Clarify when “termination of discussions” occurs (mutual written notice, after X days of inactivity, or execution/termination of a definitive agreement).
# - Consider including a severability clause and assignment restrictions.
# - If sensitive technical data subject to export controls, add export-control compliance obligations.
#
# If you want, I can:
# - Draft a revised NDA confidentiality clause that incorporates these fixes, or
# - Produce short model language snippets for any of the specific fixes above (e.g., compelled disclosure, return/destruction certification, permitted recipients).
#
# --------------------------------------------------------------------------------
# Final_reviewer_Agent (to cordinator_Agent):
#
# Good, your review covers most of the important issues. I'll verify, tighten some points, add any items I think are missing, and give short model-language snippets you can drop into the clause. I’ll flag the highest legal/practical risks first.
#
# Top risks (must-fix)
# - No duration/survival: Leaving the confidentiality term open creates uncertainty and litigation risk. Add a finite term (e.g., 2–5 years) and separate trade-secret survival (for as long as information remains a trade secret).
# - Vague definitions: “Non-public information” and “strictly confidential” are vague and invite disputes. Define “Confidential Information” and set a measurable standard of care.
# - Missing standard exclusions: Add the usual carve-outs (public, already known, independently developed, third-party rightfully disclosed) and a compelled-disclosure procedure.
# - No permitted recipients: The clause prohibits all disclosures but is impractical — permit need-to-know disclosures to employees, advisors, affiliates (bound by confidentiality) and make Recipient liable for their breaches.
# - No return/destruction timing or certification and no treatment of backups: Require a timeframe and a certificate of destruction, and address archived/backups.
# - No IP/no-license language: Silence can be interpreted as granting rights. State explicitly that no license or ownership transfer is granted.
# - No data-security or breach-notification requirement: If the information includes personal or sensitive data, require minimum security measures and prompt breach notice.
# - No governing law/jurisdiction or remedies: Add law/venue and an injunctive-relief clause (common for confidentiality breaches).
#
# Secondary risks / improvements
# - Oral disclosures: Add requirement that oral disclosures be confirmed in writing within a short period (e.g., 30 days).
# - Residuals/inevitable disclosure: Consider a residuals clause or an “inevitable disclosure” protection depending on bargaining power and enforceability in your jurisdiction.
# - Personal data / regulatory compliance: If client lists include personal data, add a compliance/processing clause or reference a Data Processing Agreement.
# - Ambiguous termination trigger: Define when “termination of discussions” happens.
# - Export controls, assignment, severability, notice details — add if relevant.
#
# Recommended, concise model language snippets
# (Replace placeholders [X], [Y], [Z] with your choices)
#
# 1) Definition of Confidential Information
# “Confidential Information means all non-public information, whether written, oral, electronic or otherwise, disclosed by the Disclosing Party to the Receiving Party, including without limitation technical data, business plans, customer and client lists, pricing, financial information, prototypes, source code and other proprietary information. Confidential Information does not include information that falls within the exclusions set out below.”
#
# 2) Exclusions (standard carve-outs)
# “Confidential Information does not include information that: (a) is or becomes publicly available through no breach by the Receiving Party; (b) was already lawfully in the Receiving Party’s possession prior to disclosure, as evidenced by written records; (c) is independently developed by the Receiving Party without use of the Disclosing Party’s Confidential Information; or (d) is rightfully received from a third party without restriction on disclosure.”
#
# 3) Standard of care
# “The Receiving Party shall protect Confidential Information with at least the same degree of care it uses to protect its own confidential information, but in no event less than reasonable care.”
#
# 4) Permitted recipients and use limitation
# “Receiving Party may use Confidential Information solely to evaluate or negotiate the proposed business relationship and for no other purpose without prior written consent. Receiving Party may disclose Confidential Information only to its employees, directors, officers, affiliates, legal counsel, accountants and professional advisors who have a need to know and are bound to protect the information at least as stringently as this Agreement; Receiving Party remains liable for breaches by such persons.”
#
# 5) Duration and survival
# “Confidentiality obligations shall continue for [three (3)] years from the date of disclosure, except that Confidential Information that qualifies as a trade secret under applicable law shall remain protected for as long as it remains a trade secret.”
#
# 6) Return/destruction; certification; archival/backups
# “Within thirty (30) days after written request or termination of discussions, Receiving Party shall (at Disclosing Party’s option) return or destroy all Confidential Information (including copies and extracts). Receiving Party shall certify in writing within fifteen (15) days that it has complied. Notwithstanding the foregoing, Receiving Party may retain one archival copy in its encrypted, access-controlled backup systems solely for recordkeeping or legal compliance purposes; such retained copy remains subject to the confidentiality obligations hereunder.”
#
# 7) Compelled disclosure
# “If Receiving Party is legally compelled to disclose Confidential Information, it shall (to the extent legally permitted) promptly notify Disclosing Party, cooperate in seeking protective measures, and disclose only the portion of Confidential Information legally required.”
#
# 8) No license / ownership
# “Nothing in this Agreement grants any license, implied or otherwise, or transfers ownership of any intellectual property rights in the Confidential Information to the Receiving Party.”
#
# 9) Security and breach notification
# “Receiving Party shall implement and maintain reasonable administrative, technical and physical security measures appropriate to the sensitivity of the Confidential Information. If Receiving Party learns of any unauthorized access, use or disclosure of Confidential Information, it shall notify Disclosing Party promptly and take all reasonable steps to mitigate harm.”
#
# 10) Remedies / injunctive relief
# “Receiving Party acknowledges that monetary damages may be inadequate and Disclosing Party shall be entitled to seek injunctive relief or other equitable remedies in addition to any other remedies at law or in equity.”
#
# 11) Residuals (optional)
# “Information retained solely in the unaided memory of individuals who have had lawful access to Confidential Information may be used by such individuals without restriction, provided that no physical or electronic copies are retained or used and no deliberate efforts were made to memorize or transcribe Confidential Information. This clause does not reduce or limit Disclosing Party’s right to seek injunctive relief for actual or threatened misuse of trade secrets.”
#
# 12) Governing law and venue
# “This Agreement shall be governed by the laws of [State/Country]. The parties submit to the exclusive jurisdiction of the courts of [State/Country] for any dispute arising under this Agreement.”
#
# 13) Oral disclosures
# “Any Confidential Information disclosed orally shall be identified as confidential at the time of disclosure and summarized in writing and delivered to Receiving Party within thirty (30) days after disclosure; otherwise such oral disclosure will not be treated as Confidential Information.”
#
# 14) Miscellaneous (short suggestions)
# - Add severability and assignment restrictions.
# - Define “termination of discussions” (e.g., mutual written notice or ninety (90) days of inactivity).
#
# Practical choices you need to make (I can draft final text once you pick)
# - Confidentiality term (common: 2–5 years; trade secrets survive indefinitely)
# - Whether to include residuals (some parties resist residuals)
# - Governing law and forum
# - Timeframe for return/destruction and certification (commonly 30 days)
#
# Next steps
# - I can draft a tidy replacement NDA clause that integrates the above defaults (I’ll use 3 years for general confidentiality and trade-secret survival unless you prefer otherwise).
# - Or I can produce tailored snippets for any single item above (e.g., compelled-disclosure procedure or data protection clause).
#
# Disclaimer: This is a content review and drafting assistance and does not substitute for legal advice. Consider having a licensed attorney in the relevant jurisdiction review final language.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (3fc6b59b-fbc1-45ad-8820-cef0b90f6c62): Maximum turns (1) reached
# cordinator_Agent (to UserProxyAgent):
#
# Good, your review covers most of the important issues. I'll verify, tighten some points, add any items I think are missing, and give short model-language snippets you can drop into the clause. I’ll flag the highest legal/practical risks first.
#
# Top risks (must-fix)
# - No duration/survival: Leaving the confidentiality term open creates uncertainty and litigation risk. Add a finite term (e.g., 2–5 years) and separate trade-secret survival (for as long as information remains a trade secret).
# - Vague definitions: “Non-public information” and “strictly confidential” are vague and invite disputes. Define “Confidential Information” and set a measurable standard of care.
# - Missing standard exclusions: Add the usual carve-outs (public, already known, independently developed, third-party rightfully disclosed) and a compelled-disclosure procedure.
# - No permitted recipients: The clause prohibits all disclosures but is impractical — permit need-to-know disclosures to employees, advisors, affiliates (bound by confidentiality) and make Recipient liable for their breaches.
# - No return/destruction timing or certification and no treatment of backups: Require a timeframe and a certificate of destruction, and address archived/backups.
# - No IP/no-license language: Silence can be interpreted as granting rights. State explicitly that no license or ownership transfer is granted.
# - No data-security or breach-notification requirement: If the information includes personal or sensitive data, require minimum security measures and prompt breach notice.
# - No governing law/jurisdiction or remedies: Add law/venue and an injunctive-relief clause (common for confidentiality breaches).
#
# Secondary risks / improvements
# - Oral disclosures: Add requirement that oral disclosures be confirmed in writing within a short period (e.g., 30 days).
# - Residuals/inevitable disclosure: Consider a residuals clause or an “inevitable disclosure” protection depending on bargaining power and enforceability in your jurisdiction.
# - Personal data / regulatory compliance: If client lists include personal data, add a compliance/processing clause or reference a Data Processing Agreement.
# - Ambiguous termination trigger: Define when “termination of discussions” happens.
# - Export controls, assignment, severability, notice details — add if relevant.
#
# Recommended, concise model language snippets
# (Replace placeholders [X], [Y], [Z] with your choices)
#
# 1) Definition of Confidential Information
# “Confidential Information means all non-public information, whether written, oral, electronic or otherwise, disclosed by the Disclosing Party to the Receiving Party, including without limitation technical data, business plans, customer and client lists, pricing, financial information, prototypes, source code and other proprietary information. Confidential Information does not include information that falls within the exclusions set out below.”
#
# 2) Exclusions (standard carve-outs)
# “Confidential Information does not include information that: (a) is or becomes publicly available through no breach by the Receiving Party; (b) was already lawfully in the Receiving Party’s possession prior to disclosure, as evidenced by written records; (c) is independently developed by the Receiving Party without use of the Disclosing Party’s Confidential Information; or (d) is rightfully received from a third party without restriction on disclosure.”
#
# 3) Standard of care
# “The Receiving Party shall protect Confidential Information with at least the same degree of care it uses to protect its own confidential information, but in no event less than reasonable care.”
#
# 4) Permitted recipients and use limitation
# “Receiving Party may use Confidential Information solely to evaluate or negotiate the proposed business relationship and for no other purpose without prior written consent. Receiving Party may disclose Confidential Information only to its employees, directors, officers, affiliates, legal counsel, accountants and professional advisors who have a need to know and are bound to protect the information at least as stringently as this Agreement; Receiving Party remains liable for breaches by such persons.”
#
# 5) Duration and survival
# “Confidentiality obligations shall continue for [three (3)] years from the date of disclosure, except that Confidential Information that qualifies as a trade secret under applicable law shall remain protected for as long as it remains a trade secret.”
#
# 6) Return/destruction; certification; archival/backups
# “Within thirty (30) days after written request or termination of discussions, Receiving Party shall (at Disclosing Party’s option) return or destroy all Confidential Information (including copies and extracts). Receiving Party shall certify in writing within fifteen (15) days that it has complied. Notwithstanding the foregoing, Receiving Party may retain one archival copy in its encrypted, access-controlled backup systems solely for recordkeeping or legal compliance purposes; such retained copy remains subject to the confidentiality obligations hereunder.”
#
# 7) Compelled disclosure
# “If Receiving Party is legally compelled to disclose Confidential Information, it shall (to the extent legally permitted) promptly notify Disclosing Party, cooperate in seeking protective measures, and disclose only the portion of Confidential Information legally required.”
#
# 8) No license / ownership
# “Nothing in this Agreement grants any license, implied or otherwise, or transfers ownership of any intellectual property rights in the Confidential Information to the Receiving Party.”
#
# 9) Security and breach notification
# “Receiving Party shall implement and maintain reasonable administrative, technical and physical security measures appropriate to the sensitivity of the Confidential Information. If Receiving Party learns of any unauthorized access, use or disclosure of Confidential Information, it shall notify Disclosing Party promptly and take all reasonable steps to mitigate harm.”
#
# 10) Remedies / injunctive relief
# “Receiving Party acknowledges that monetary damages may be inadequate and Disclosing Party shall be entitled to seek injunctive relief or other equitable remedies in addition to any other remedies at law or in equity.”
#
# 11) Residuals (optional)
# “Information retained solely in the unaided memory of individuals who have had lawful access to Confidential Information may be used by such individuals without restriction, provided that no physical or electronic copies are retained or used and no deliberate efforts were made to memorize or transcribe Confidential Information. This clause does not reduce or limit Disclosing Party’s right to seek injunctive relief for actual or threatened misuse of trade secrets.”
#
# 12) Governing law and venue
# “This Agreement shall be governed by the laws of [State/Country]. The parties submit to the exclusive jurisdiction of the courts of [State/Country] for any dispute arising under this Agreement.”
#
# 13) Oral disclosures
# “Any Confidential Information disclosed orally shall be identified as confidential at the time of disclosure and summarized in writing and delivered to Receiving Party within thirty (30) days after disclosure; otherwise such oral disclosure will not be treated as Confidential Information.”
#
# 14) Miscellaneous (short suggestions)
# - Add severability and assignment restrictions.
# - Define “termination of discussions” (e.g., mutual written notice or ninety (90) days of inactivity).
#
# Practical choices you need to make (I can draft final text once you pick)
# - Confidentiality term (common: 2–5 years; trade secrets survive indefinitely)
# - Whether to include residuals (some parties resist residuals)
# - Governing law and forum
# - Timeframe for return/destruction and certification (commonly 30 days)
#
# Next steps
# - I can draft a tidy replacement NDA clause that integrates the above defaults (I’ll use 3 years for general confidentiality and trade-secret survival unless you prefer otherwise).
# - Or I can produce tailored snippets for any single item above (e.g., compelled-disclosure procedure or data protection clause).
#
# Disclaimer: This is a content review and drafting assistance and does not substitute for legal advice. Consider having a licensed attorney in the relevant jurisdiction review final language.
#
# --------------------------------------------------------------------------------
# Replying as UserProxyAgent. Provide feedback to cordinator_Agent. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  0k
# UserProxyAgent (to cordinator_Agent):
#
# 0k
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (cc55b32e-d789-4478-b1c5-9700a9136390): Maximum turns (2) reached

# %%
cordinator.chat_messages
# Out:
# defaultdict(list,
#             {<autogen.agentchat.user_proxy_agent.UserProxyAgent at 0x1d98ea7d050>: [{'content': ' Please provide the legal content',
#                'role': 'assistant',
#                'name': 'cordinator_Agent'},
#               {'content': 'The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.',
#                'role': 'user',
#                'name': 'UserProxyAgent'},
#               {'content': "Good, your review covers most of the important issues. I'll verify, tighten some points, add any items I think are missing, and give short model-language snippets you can drop into the clause. I’ll flag the highest legal/practical risks first.\n\nTop risks (must-fix)\n- No duration/survival: Leaving the confidentiality term open creates uncertainty and litigation risk. Add a finite term (e.g., 2–5 years) and separate trade-secret survival (for as long as information remains a trade secret).\n- Vague definitions: “Non-public information” and “strictly confidential” are vague and invite disputes. Define “Confidential Information” and set a measurable standard of care.\n- Missing standard exclusions: Add the usual carve-outs (public, already known, independently developed, third-party rightfully disclosed) and a compelled-disclosure procedure.\n- No permitted recipients: The clause prohibits all disclosures but is impractical — permit need-to-know disclosures to employees, advisors, affiliates (bound by confidentiality) and make Recipient liable for their breaches.\n- No return/destruction timing or certification and no treatment of backups: Require a timeframe and a certificate of destruction, and address archived/backups.\n- No IP/no-license language: Silence can be interpreted as granting rights. State explicitly that no license or ownership transfer is granted.\n- No data-security or breach-notification requirement: If the information includes personal or sensitive data, require minimum security measures and prompt breach notice.\n- No governing law/jurisdiction or remedies: Add law/venue and an injunctive-relief clause (common for confidentiality breaches).\n\nSecondary risks / improvements\n- Oral disclosures: Add requirement that oral disclosures be confirmed in writing within a short period (e.g., 30 days).\n- Residuals/inevitable disclosure: Consider a residuals clause or an “inevitable disclosure” protection depending on bargaining power and enforceability in your jurisdiction.\n- Personal data / regulatory compliance: If client lists include personal data, add a compliance/processing clause or reference a Data Processing Agreement.\n- Ambiguous termination trigger: Define when “termination of discussions” happens.\n- Export controls, assignment, severability, notice details — add if relevant.\n\nRecommended, concise model language snippets\n(Replace placeholders [X], [Y], [Z] with your choices)\n\n1) Definition of Confidential Information\n“Confidential Information means all non-public information, whether written, oral, electronic or otherwise, disclosed by the Disclosing Party to the Receiving Party, including without limitation technical data, business plans, customer and client lists, pricing, financial information, prototypes, source code and other proprietary information. Confidential Information does not include information that falls within the exclusions set out below.”\n\n2) Exclusions (standard carve-outs)\n“Confidential Information does not include information that: (a) is or becomes publicly available through no breach by the Receiving Party; (b) was already lawfully in the Receiving Party’s possession prior to disclosure, as evidenced by written records; (c) is independently developed by the Receiving Party without use of the Disclosing Party’s Confidential Information; or (d) is rightfully received from a third party without restriction on disclosure.”\n\n3) Standard of care\n“The Receiving Party shall protect Confidential Information with at least the same degree of care it uses to protect its own confidential information, but in no event less than reasonable care.”\n\n4) Permitted recipients and use limitation\n“Receiving Party may use Confidential Information solely to evaluate or negotiate the proposed business relationship and for no other purpose without prior written consent. Receiving Party may disclose Confidential Information only to its employees, directors, officers ...
#                'role': 'assistant',
#                'name': 'cordinator_Agent'},
#               {'content': '0k', 'role': 'user', 'name': 'UserProxyAgent'}],
#              <autogen.agentchat.conversable_agent.ConversableAgent at 0x1d99c7c7250>: [{'content': 'The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.',
#                'role': 'assistant',
#                'name': 'cordinator_Agent'},
#               {'content': '- Definition of Confidential Information  \n  - All non-public information received from the Disclosing Party; explicitly includes “technical data, business plans, and client lists.”\n\n- Confidentiality obligation (non-disclosure/non-publication)  \n  - The Receiving Party “agrees to treat all non-public information … as strictly confidential” and “shall not disclose [or] publish” the information.\n\n- Non-use / purpose limitation  \n  - The Receiving Party shall not “use this information for any purpose other than evaluating the proposed business relationship.”\n\n- Prior written consent for other uses/disclosures  \n  - Any use or disclosure outside the permitted purpose requires “prior written consent.”\n\n- Exclusion / carve-out for public information  \n  - The obligation does not apply to information “that is publicly known through no fault of the Receiving Party.”\n\n- Return or destruction on termination  \n  - “Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.”\n\n- Parties referenced  \n  - Terms apply between the “Receiving Party” and the “Disclosing Party.”',
#                'role': 'user',
#                'name': 'key_clause_extractor_Agent'}],
#              <autogen.agentchat.conversable_agent.ConversableAgent at 0x1d99c7ef0d0>: [{'content': 'The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.\nContext: \n- Definition of Confidential Information  \n  - All non-public information received from the Disclosing Party; explicitly includes “technical data, business plans, and client lists.”\n\n- Confidentiality obligation (non-disclosure/non-publication)  \n  - The Receiving Party “agrees to treat all non-public information … as strictly confidential” and “shall not disclose [or] publish” the information.\n\n- Non-use / purpose limitation  \n  - The Receiving Party shall not “use this information for any purpose other than evaluating the proposed business relationship.”\n\n- Prior written consent for other uses/disclosures  \n  - Any use or disclosure outside the permitted purpose requires “prior written consent.”\n\n- Exclusion / carve-out for public information  \n  - The obligation does not apply to information “that is publicly known through no fault of the Receiving Party.”\n\n- Return or destruction on termination  \n  - “Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.”\n\n- Parties referenced  \n  - Terms apply between the “Receiving Party” and the “Disclosing Party.”',
#                'role': 'assistant',
#                'name': 'cordinator_Agent'},
#               {'content': 'I reviewed the provided confidentiality clause. Below are the risks, why they matter, and recommended fixes (grouped by priority).\n\nHigh priority (practical/legal exposure)\n- No confidentiality duration or survival clause\n  - Risk: Unknown how long obligation lasts (exposure both ways). Courts often expect a finite term unless trade-secret protection intended.\n  - Fix: Add a fixed term (e.g., "for a period of X years from the date of disclosure") and a separate survival statement for trade secrets (e.g., "trade secrets remain protected for as long as they qualify as trade secrets").\n\n- No definition/standard for “non-public” or “strictly confidential”\n  - Risk: Ambiguity invites disputes about what counts as confidential; “strictly confidential” is subjective.\n  - Fix: Define “Confidential Information” precisely (include examples) and specify standard of care (e.g., “Receiving Party will protect Confidential Information with at least the same degree of care it uses for its own confidential information, but no less than reasonable care”).\n\n- No exceptions beyond “publicly known through no fault”\n  - Risk: Missing customary carve-outs (information already known to Receiving Party, independently developed, disclosed by third party without restriction, or required disclosure by law).\n  - Fix: Add standard exclusions: (a) publicly available through no breach; (b) already in Receiving Party’s possession before disclosure (with proof); (c) independently developed by Receiving Party without use of Confidential Information; (d) rightfully received from third party without restriction. Add compelled-disclosure procedure (notice to Disclosing Party, cooperation, seek protective order).\n\n- No permitted recipients or treatment of employees/affiliates/advisors\n  - Risk: Overly strict “no disclosure” may prevent reasonable internal sharing for evaluation or sharing with advisors (legal/accounting), which is impractical.\n  - Fix: Allow disclosures to Receiving Party’s employees, consultants, advisors and affiliates who have a need-to-know and are bound by confidentiality obligations at least as protective as this agreement. Require Recipient to remain liable for their breaches.\n\nMedium priority (operational/compliance risks)\n- No requirement for data security measures or breach notification\n  - Risk: Particularly where Confidential Information includes personal data or sensitive technical info, lack of security specs raises compliance and reputational risk.\n  - Fix: Specify minimum security measures (e.g., industry-standard technical and organizational measures) and a timely breach-notification obligation.\n\n- No return/destruction timing or certification\n  - Risk: “Return or destroy” without timeframe or certification leaves uncertainty and enforcement problems (esp. backups).\n  - Fix: Require return or certified destruction within a set period (e.g., 30 days) after termination/expiration, and permit Recipient to retain one archival copy for legal/ compliance recordkeeping if required (with continued confidentiality).\n\n- No “no license” / IP ownership clause\n  - Risk: Ambiguity may suggest transfer of rights or implied license to use IP.\n  - Fix: Add explicit statement that disclosure does not grant any license or transfer of intellectual property; ownership remains with Disclosing Party.\n\n- Narrow permitted purpose / prior written consent burden\n  - Risk: Restricting use strictly to “evaluating the proposed business relationship” may be impractical for follow-up integration work or limited permitted uses; always requiring prior written consent can cause delays.\n  - Fix: Clarify permitted use (e.g., evaluation and bona fide internal business purposes related to the proposed relationship) and permit disclosures to permitted recipients without separate approvals, while requiring prior written consent only for other uses.\n\nLow–medium priority (enforceability/clarity)\n- No remedies o ...
#                'role': 'user',
#                'name': 'Risk_flagger_Agent'}],
#              <autogen.agentchat.conversable_agent.ConversableAgent at 0x1d99c804bd0>: [{'content': 'The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.\nContext: \n0\n1\n- Definition of Confidential Information  \n  - All non-public information received from the Disclosing Party; explicitly includes “technical data, business plans, and client lists.”\n\n- Confidentiality obligation (non-disclosure/non-publication)  \n  - The Receiving Party “agrees to treat all non-public information … as strictly confidential” and “shall not disclose [or] publish” the information.\n\n- Non-use / purpose limitation  \n  - The Receiving Party shall not “use this information for any purpose other than evaluating the proposed business relationship.”\n\n- Prior written consent for other uses/disclosures  \n  - Any use or disclosure outside the permitted purpose requires “prior written consent.”\n\n- Exclusion / carve-out for public information  \n  - The obligation does not apply to information “that is publicly known through no fault of the Receiving Party.”\n\n- Return or destruction on termination  \n  - “Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.”\n\n- Parties referenced  \n  - Terms apply between the “Receiving Party” and the “Disclosing Party.”\nI reviewed the provided confidentiality clause. Below are the risks, why they matter, and recommended fixes (grouped by priority).\n\nHigh priority (practical/legal exposure)\n- No confidentiality duration or survival clause\n  - Risk: Unknown how long obligation lasts (exposure both ways). Courts often expect a finite term unless trade-secret protection intended.\n  - Fix: Add a fixed term (e.g., "for a period of X years from the date of disclosure") and a separate survival statement for trade secrets (e.g., "trade secrets remain protected for as long as they qualify as trade secrets").\n\n- No definition/standard for “non-public” or “strictly confidential”\n  - Risk: Ambiguity invites disputes about what counts as confidential; “strictly confidential” is subjective.\n  - Fix: Define “Confidential Information” precisely (include examples) and specify standard of care (e.g., “Receiving Party will protect Confidential Information with at least the same degree of care it uses for its own confidential information, but no less than reasonable care”).\n\n- No exceptions beyond “publicly known through no fault”\n  - Risk: Missing customary carve-outs (information already known to Receiving Party, independently developed, disclosed by third party without restriction, or required disclosure by law).\n  - Fix: Add standard exclusions: (a) publicly available through no breach; (b) already in Receiving Party’s possession before disclosure (with proof); (c) independently developed by Receiving Party without use of Confidential Information; (d) rightfully received from third party without restriction. Add compelled-disclosure procedure (notice to Disclosing Party, cooperation, seek protective order).\n\n- No permitted recipients or treatment of employees/affiliates/advisors\n  - Risk: Overly strict “no disclosure” may prevent reasonable internal sharing for evaluation or sharing with advisors (legal/accounting), which is impractical.\n  - Fix: Allow disclosures to Receiving Party’s employees, consultants, advisors and affiliates who have a need-to-know and are bound by confidentiality obligations at least as protective ...
#                'role': 'assistant',
#                'name': 'cordinator_Agent'},
#               {'content': "Good, your review covers most of the important issues. I'll verify, tighten some points, add any items I think are missing, and give short model-language snippets you can drop into the clause. I’ll flag the highest legal/practical risks first.\n\nTop risks (must-fix)\n- No duration/survival: Leaving the confidentiality term open creates uncertainty and litigation risk. Add a finite term (e.g., 2–5 years) and separate trade-secret survival (for as long as information remains a trade secret).\n- Vague definitions: “Non-public information” and “strictly confidential” are vague and invite disputes. Define “Confidential Information” and set a measurable standard of care.\n- Missing standard exclusions: Add the usual carve-outs (public, already known, independently developed, third-party rightfully disclosed) and a compelled-disclosure procedure.\n- No permitted recipients: The clause prohibits all disclosures but is impractical — permit need-to-know disclosures to employees, advisors, affiliates (bound by confidentiality) and make Recipient liable for their breaches.\n- No return/destruction timing or certification and no treatment of backups: Require a timeframe and a certificate of destruction, and address archived/backups.\n- No IP/no-license language: Silence can be interpreted as granting rights. State explicitly that no license or ownership transfer is granted.\n- No data-security or breach-notification requirement: If the information includes personal or sensitive data, require minimum security measures and prompt breach notice.\n- No governing law/jurisdiction or remedies: Add law/venue and an injunctive-relief clause (common for confidentiality breaches).\n\nSecondary risks / improvements\n- Oral disclosures: Add requirement that oral disclosures be confirmed in writing within a short period (e.g., 30 days).\n- Residuals/inevitable disclosure: Consider a residuals clause or an “inevitable disclosure” protection depending on bargaining power and enforceability in your jurisdiction.\n- Personal data / regulatory compliance: If client lists include personal data, add a compliance/processing clause or reference a Data Processing Agreement.\n- Ambiguous termination trigger: Define when “termination of discussions” happens.\n- Export controls, assignment, severability, notice details — add if relevant.\n\nRecommended, concise model language snippets\n(Replace placeholders [X], [Y], [Z] with your choices)\n\n1) Definition of Confidential Information\n“Confidential Information means all non-public information, whether written, oral, electronic or otherwise, disclosed by the Disclosing Party to the Receiving Party, including without limitation technical data, business plans, customer and client lists, pricing, financial information, prototypes, source code and other proprietary information. Confidential Information does not include information that falls within the exclusions set out below.”\n\n2) Exclusions (standard carve-outs)\n“Confidential Information does not include information that: (a) is or becomes publicly available through no breach by the Receiving Party; (b) was already lawfully in the Receiving Party’s possession prior to disclosure, as evidenced by written records; (c) is independently developed by the Receiving Party without use of the Disclosing Party’s Confidential Information; or (d) is rightfully received from a third party without restriction on disclosure.”\n\n3) Standard of care\n“The Receiving Party shall protect Confidential Information with at least the same degree of care it uses to protect its own confidential information, but in no event less than reasonable care.”\n\n4) Permitted recipients and use limitation\n“Receiving Party may use Confidential Information solely to evaluate or negotiate the proposed business relationship and for no other purpose without prior written consent. Receiving Party may disclose Confidential Information only to its employees, directors, officers ...
#                'role': 'user',
#                'name': 'Final_reviewer_Agent'}]})

# %%
cordinator.chat_messages_for_summary(User_proxy)
# Out:
# [{'content': ' Please provide the legal content',
#   'role': 'assistant',
#   'name': 'cordinator_Agent'},
#  {'content': 'The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.',
#   'role': 'user',
#   'name': 'UserProxyAgent'},
#  {'content': "Good, your review covers most of the important issues. I'll verify, tighten some points, add any items I think are missing, and give short model-language snippets you can drop into the clause. I’ll flag the highest legal/practical risks first.\n\nTop risks (must-fix)\n- No duration/survival: Leaving the confidentiality term open creates uncertainty and litigation risk. Add a finite term (e.g., 2–5 years) and separate trade-secret survival (for as long as information remains a trade secret).\n- Vague definitions: “Non-public information” and “strictly confidential” are vague and invite disputes. Define “Confidential Information” and set a measurable standard of care.\n- Missing standard exclusions: Add the usual carve-outs (public, already known, independently developed, third-party rightfully disclosed) and a compelled-disclosure procedure.\n- No permitted recipients: The clause prohibits all disclosures but is impractical — permit need-to-know disclosures to employees, advisors, affiliates (bound by confidentiality) and make Recipient liable for their breaches.\n- No return/destruction timing or certification and no treatment of backups: Require a timeframe and a certificate of destruction, and address archived/backups.\n- No IP/no-license language: Silence can be interpreted as granting rights. State explicitly that no license or ownership transfer is granted.\n- No data-security or breach-notification requirement: If the information includes personal or sensitive data, require minimum security measures and prompt breach notice.\n- No governing law/jurisdiction or remedies: Add law/venue and an injunctive-relief clause (common for confidentiality breaches).\n\nSecondary risks / improvements\n- Oral disclosures: Add requirement that oral disclosures be confirmed in writing within a short period (e.g., 30 days).\n- Residuals/inevitable disclosure: Consider a residuals clause or an “inevitable disclosure” protection depending on bargaining power and enforceability in your jurisdiction.\n- Personal data / regulatory compliance: If client lists include personal data, add a compliance/processing clause or reference a Data Processing Agreement.\n- Ambiguous termination trigger: Define when “termination of discussions” happens.\n- Export controls, assignment, severability, notice details — add if relevant.\n\nRecommended, concise model language snippets\n(Replace placeholders [X], [Y], [Z] with your choices)\n\n1) Definition of Confidential Information\n“Confidential Information means all non-public information, whether written, oral, electronic or otherwise, disclosed by the Disclosing Party to the Receiving Party, including without limitation technical data, business plans, customer and client lists, pricing, financial information, prototypes, source code and other proprietary information. Confidential Information does not include information that falls within the exclusions set out below.”\n\n2) Exclusions (standard carve-outs)\n“Confidential Information does not include information that: (a) is or becomes publicly available through no breach by the Receiving Party; (b) was already lawfully in the Receiving Party’s possession prior to disclosure, as evidenced by written records; (c) is independently developed by the Receiving Party without use of the Disclosing Party’s Confidential Information; or (d) is rightfully received from a third party without restriction on disclosure.”\n\n3) Standard of care\n“The Receiving Party shall protect Confidential Information with at least the same degree of care it uses to protect its own confidential information, but in no event less than reasonable care.”\n\n4) Permitted recipients and use limitation\n“Receiving Party may use Confidential Information solely to evaluate or negotiate the proposed business relationship and for no other purpose without prior written consent. Receiving Party may disclose Confidential Information only to its employees, directors, officers, affiliates, ...
#   'role': 'assistant',
#   'name': 'cordinator_Agent'},
#  {'content': '0k', 'role': 'user', 'name': 'UserProxyAgent'}]

# %%
cordinator.chat_messages_for_summary(User_proxy)[-1]['content']
# Out:
# '0k'

# %%
dir(chat_queue)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
chats.chat_history
# Out:
# [{'content': ' Please provide the legal content',
#   'role': 'assistant',
#   'name': 'cordinator_Agent'},
#  {'content': 'The Receiving Party agrees to treat all non-public information received     from the Disclosing Party as strictly confidential. This includes technical data, business plans, and client lists.     The Receiving Party shall not disclose, publish, or use this information for any purpose other than evaluating the proposed business relationship without prior written consent.     This obligation does not apply to information that is publicly known through no fault of the Receiving Party.     Upon termination of discussions, the Receiving Party shall return or destroy all confidential materials.',
#   'role': 'user',
#   'name': 'UserProxyAgent'},
#  {'content': "Good, your review covers most of the important issues. I'll verify, tighten some points, add any items I think are missing, and give short model-language snippets you can drop into the clause. I’ll flag the highest legal/practical risks first.\n\nTop risks (must-fix)\n- No duration/survival: Leaving the confidentiality term open creates uncertainty and litigation risk. Add a finite term (e.g., 2–5 years) and separate trade-secret survival (for as long as information remains a trade secret).\n- Vague definitions: “Non-public information” and “strictly confidential” are vague and invite disputes. Define “Confidential Information” and set a measurable standard of care.\n- Missing standard exclusions: Add the usual carve-outs (public, already known, independently developed, third-party rightfully disclosed) and a compelled-disclosure procedure.\n- No permitted recipients: The clause prohibits all disclosures but is impractical — permit need-to-know disclosures to employees, advisors, affiliates (bound by confidentiality) and make Recipient liable for their breaches.\n- No return/destruction timing or certification and no treatment of backups: Require a timeframe and a certificate of destruction, and address archived/backups.\n- No IP/no-license language: Silence can be interpreted as granting rights. State explicitly that no license or ownership transfer is granted.\n- No data-security or breach-notification requirement: If the information includes personal or sensitive data, require minimum security measures and prompt breach notice.\n- No governing law/jurisdiction or remedies: Add law/venue and an injunctive-relief clause (common for confidentiality breaches).\n\nSecondary risks / improvements\n- Oral disclosures: Add requirement that oral disclosures be confirmed in writing within a short period (e.g., 30 days).\n- Residuals/inevitable disclosure: Consider a residuals clause or an “inevitable disclosure” protection depending on bargaining power and enforceability in your jurisdiction.\n- Personal data / regulatory compliance: If client lists include personal data, add a compliance/processing clause or reference a Data Processing Agreement.\n- Ambiguous termination trigger: Define when “termination of discussions” happens.\n- Export controls, assignment, severability, notice details — add if relevant.\n\nRecommended, concise model language snippets\n(Replace placeholders [X], [Y], [Z] with your choices)\n\n1) Definition of Confidential Information\n“Confidential Information means all non-public information, whether written, oral, electronic or otherwise, disclosed by the Disclosing Party to the Receiving Party, including without limitation technical data, business plans, customer and client lists, pricing, financial information, prototypes, source code and other proprietary information. Confidential Information does not include information that falls within the exclusions set out below.”\n\n2) Exclusions (standard carve-outs)\n“Confidential Information does not include information that: (a) is or becomes publicly available through no breach by the Receiving Party; (b) was already lawfully in the Receiving Party’s possession prior to disclosure, as evidenced by written records; (c) is independently developed by the Receiving Party without use of the Disclosing Party’s Confidential Information; or (d) is rightfully received from a third party without restriction on disclosure.”\n\n3) Standard of care\n“The Receiving Party shall protect Confidential Information with at least the same degree of care it uses to protect its own confidential information, but in no event less than reasonable care.”\n\n4) Permitted recipients and use limitation\n“Receiving Party may use Confidential Information solely to evaluate or negotiate the proposed business relationship and for no other purpose without prior written consent. Receiving Party may disclose Confidential Information only to its employees, directors, officers, affiliates, ...
#   'role': 'assistant',
#   'name': 'cordinator_Agent'},
#  {'content': '0k', 'role': 'user', 'name': 'UserProxyAgent'}]
